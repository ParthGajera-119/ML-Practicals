# %%
mylist=['tom','bob','jerry']
mylist
# Out:
# ['tom', 'bob', 'jerry']

# %%
len(Mylist)
# Out:
# 3

# %%
mylist2=[1,2,3,4,5]
mylist2
# Out:
# [1, 2, 3, 4, 5]

# %%
mylist3=[True,True,False,True]
mylist3
# Out:
# [True, True, False, True]

# %%
type(mylist2)
# Out:
# list

# %%
mylist[1]
mylist[-2]
# Out:
# 'bob'

# %%
mylist2[0:3]
mylist3[1:]
mylist[:3]
# Out:
# ['tom', 'bob', 'jerry']

# %%
mylist3[1]=False
mylist3
# Out:
# [True, False, False, True]

# %%
mylist2[1:3]=[10,15]
mylist2
# Out:
# [1, 10, 15, 4, 5]

# %%
mylist2[1:3]=[2]
mylist2
# Out:
# [1, 2, 4, 5]

# %%
mylist.insert(1,'john')
mylist
# Out:
# ['tom', 'john', 'bob', 'jerry']

# %%
mylist.insert(4,'michael')
mylist
# Out:
# ['tom', 'john', 'bob', 'jerry', 'michael']

# %%
mylist2.append(6)
mylist2
# Out:
# [1, 2, 4, 5, 6]

# %%
mylist2.extend(mylist3)
mylist2
# Out:
# [1, 2, 4, 5, 6, True, False, False, True]

# %%
mylist.remove('bob')
mylist
# Out:
# ['tom', 'john', 'jerry', 'michael']

# %%
mylist.pop()
mylist
# Out:
# ['tom', 'john', 'jerry']

# %%
for x in mylist:
  print(x)
# Out:
# tom
# john
# jerry

# %%
newlist=[x for x in range(5)]
newlist
# Out:
# [0, 1, 2, 3, 4]

# %%
newlist1=[x.upper() for x in mylist]
newlist1
# Out:
# ['TOM', 'JOHN', 'JERRY']

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort()
thislist
# Out:
# [23, 50, 65, 82, 100]

# %%
thislist.sort(reverse=True)
thislist
# Out:
# [100, 82, 65, 50, 23]

# %%
newone=newlist+thislist
newone
# Out:
# [0, 1, 2, 3, 4, 100, 82, 65, 50, 23]

# %%
thislist1=thislist.copy()
thislist1
# Out:
# [100, 82, 65, 50, 23]

# %%
thislist.clear()
thislist
# Out:
# []
